# %%
import pyautogui
from time import sleep, time
import keyboard
from IPython.display import clear_output

# %%
'''
每秒判斷桌面上的圖片(座標)是否存在
'''

while True:
    sleep(0.1)
    
    #自動清除此格的文字輸出
    clear_output(wait = True)
    
    # 取得 Box 物件
    btn_0_location = pyautogui.locateOnScreen('images/BlueStacks.png',confidence = 0.9)
    
    print(btn_0_location)
    
    if keyboard.is_pressed('alt'):
        break
# Out:
# Box(left=7, top=7, width=128, height=38)

# %%
# 設定每一個動作，都暫停若干秒
pyautogui.PAUSE = 0.005


def click_first():    
    
     # 比對所有圖片，取得顯示在桌面的圖片物件 (pillow / PIL Image)
    btn_fastfight_location = pyautogui.locateOnScreen('images/fastfight.png', confidence=0.9)              
    # 取得每一個圖片的中心點
    btn_fastfight_point = pyautogui.center(btn_fastfight_location)    
    # 點擊圖片
    pyautogui.click(btn_fastfight_point)
        
    
        
    while True:
        try:        
            sleep(0.5)
        
            btn_continues_location = pyautogui.locateOnScreen('images/continues.png', confidence=0.9)
        
            btn_continues_point = pyautogui.center(btn_continues_location)
        
            pyautogui.click(btn_continues_point)
            
        except TypeError:
            break

def click_second():       
    sleep(0.5)
        
    btn_open_location = pyautogui.locateOnScreen('images/open.png', confidence=0.9)
        
    btn_open_point = pyautogui.center(btn_open_location)
        
    pyautogui.click(btn_open_point)
    

def click_third():
    sleep(0.5)
                 
    btn_getfewpower_location = pyautogui.locateOnScreen('images/getfewpower.png', confidence=0.9)        
            
    btn_getfewpower_point = pyautogui.center(btn_getfewpower_location)
    
    pyautogui.click(btn_getfewpower_point)
    
    sleep(0.5)
    
    while True:
        try:        
            sleep(0.5)
        
            btn_clickspace_location = pyautogui.locateOnScreen('images/clicktoleave.png', confidence=0.9)
        
            btn_clickspace_point = pyautogui.center(btn_clickspace_location)
        
            pyautogui.click(btn_clickspace_point)
            
        except TypeError:
            break
    
       
def click_fourth():
    sleep(0.5)
            
    btn_getmorepower_location = pyautogui.locateOnScreen('images/getmorepower.png', confidence=0.9)        
            
    btn_getmorepower_point = pyautogui.center(btn_getmorepower_location)
    
    pyautogui.click(btn_getmorepower_point)
    
    sleep(0.5)
    
    while True:
        try:        
            sleep(0.5)
        
            btn_clickspace_location = pyautogui.locateOnScreen('images/clicktoleave.png', confidence=0.9)
        
            btn_clickspace_point = pyautogui.center(btn_clickspace_location)
        
            pyautogui.click(btn_clickspace_point)
            
        except TypeError:
            break
                 
                    
def click_fifth():
    sleep(0.5)
             
    btn_getlotpower_location = pyautogui.locateOnScreen('imagess/getlotpower.png', confidence=0.9)        
            
    btn_getlotpower_point = pyautogui.center(btn_getlotpower_location)
    
    pyautogui.click(btn_getlotpower_point)
    
    sleep(0.5)
    
    while True:
        try:        
            sleep(0.5)
        
            btn_clickspace_location = pyautogui.locateOnScreen('images/clicktoleave.png', confidence=0.9)
        
            btn_clickspace_point = pyautogui.center(btn_clickspace_location)
        
            pyautogui.click(btn_clickspace_point)
            
        except TypeError:
            break

    
def click_sixth():
    sleep(0.5)
             
    btn_search_location = pyautogui.locateOnScreen('imagess/search.png', confidence=0.9)        
            
    btn_search_point = pyautogui.center(btn_search_location)
    
    pyautogui.click(btn_search_point)           

    
    
while True:
    print('start')
    if pyautogui.locateOnScreen('images/fastfight.png', confidence=0.9) != None:
        print('test1')
        click_first()
                        
    if pyautogui.locateOnScreen('images/open.png', confidence=0.9) != None:
        print('test2')
        click_second()
                   
    if pyautogui.locateOnScreen('images/getfewpower.png', confidence=0.9) != None:
        print('test3')
        click_third()
               
    if pyautogui.locateOnScreen('images/getmorepower.png', confidence=0.9) != None:
        print('test4')
        click_fourth()
                 
    if pyautogui.locateOnScreen('images/getlotpower.png', confidence=0.9) != None:
        print('test5')
        click_fifth()

    if pyautogui.locateOnScreen('images/search.png', confidence=0.9) != None:
        print('test6')
        click_sixth()
    
        
        
    if keyboard.is_pressed('alt'):
        break
# Out:
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# test3
# start
# start
# start
# start
# start
# test1
# start
# start
# start
# start
# start
# test3
# start
# start
# start
# start
# start
# start
# start
# test1
# start
# start
# test1
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# test6
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8056\2719034512.py in <module>
#     147     if pyautogui.locateOnScreen('images/search.png', confidence=0.9) != None:
#     148         print('test6')
# --> 149         click_sixth()
#     150
#     151
#
# ~\AppData\Local\Temp\ipykernel_8056\2719034512.py in click_sixth()
#     115     sleep(0.5)
#     116
# --> 117     btn_search_location = pyautogui.locateOnScreen('imagess/search.png', confidence=0.9)
#     118
#     119     btn_search_point = pyautogui.center(btn_search_location)
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
#     176         except pyscreeze.ImageNotFoundException:
#     177             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in locateOnScreen(*args, **kwargs)
#     211     @raisePyAutoGUIImageNotFoundException
#     212     def locateOnScreen(*args, **kwargs):
# --> 213         return pyscreeze.locateOnScreen(*args, **kwargs)
#     214
#     215     locateOnScreen.__doc__ = pyscreeze.locateOnScreen.__doc__
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     371         try:
#     372             screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 373             retVal = locate(image, screenshotIm, **kwargs)
#     374             try:
#     375                 screenshotIm.fp.close()
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     351     # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     352     kwargs['limit'] = 1
# --> 353     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     354     if len(points) > 0:
#     355         return points[0]
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     205     confidence = float(confidence)
#     206
# --> 207     needleImage = _load_cv2(needleImage, grayscale)
#     208     needleHeight, needleWidth = needleImage.shape[:2]
#     209     haystackImage = _load_cv2(haystackImage, grayscale)
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in _load_cv2(img, grayscale)
#     168             img_cv = cv2.imread(img, LOAD_COLOR)
#     169         if img_cv is None:
# --> 170             raise IOError("Failed to read %s because file is missing, "
#     171                           "has improper permissions, or is an "
#     172                           "unsupported or invalid format" % img)
#
# OSError: Failed to read imagess/search.png because file is missing, has improper permissions, or is an unsupported or invalid format
